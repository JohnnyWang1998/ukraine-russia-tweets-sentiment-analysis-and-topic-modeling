# %% [markdown]
# # EDA

# %%
import numpy as np
import pandas as pd
import seaborn as sn
from typing import List
from tqdm import tqdm

# %%
pip install emoji
# Out:
# Collecting emoji
#   Downloading emoji-1.7.0.tar.gz (175 kB)
#      |████████████████████████████████| 175 kB 5.4 MB/s
# Building wheels for collected packages: emoji
#   Building wheel for emoji (setup.py) ... done
#   Created wheel for emoji: filename=emoji-1.7.0-py3-none-any.whl size=171046 sha256=04e0be1e13b663bcec189c0b4fa6b191e3bd94ebb948b1336efaf0032aee9fb5
#   Stored in directory: /root/.cache/pip/wheels/8a/4e/b6/57b01db010d17ef6ea9b40300af725ef3e210cb1acfb7ac8b6
# Successfully built emoji
# Installing collected packages: emoji
# Successfully installed emoji-1.7.0

# %%
pip install pyLDAvis
# Out:
# Collecting pyLDAvis
#   Downloading pyLDAvis-3.3.1.tar.gz (1.7 MB)
#      |████████████████████████████████| 1.7 MB 5.4 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied: gensim in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (3.6.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.4.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.1.0)
# Requirement already satisfied: sklearn in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (0.0)
# Requirement already satisfied: numexpr in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (2.8.1)
# Requirement already satisfied: pandas>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (2.11.3)
# Collecting funcy
#   Downloading funcy-1.17-py2.py3-none-any.whl (33 kB)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (0.16.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.0.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (57.4.0)
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.21.5)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.2.0->pyLDAvis) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.2.0->pyLDAvis) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=1.2.0->pyLDAvis) (1.15.0)
# Requirement already satisfied: smart-open>=1.2.1 in /usr/local/lib/python3.7/dist-packages (from gensim->pyLDAvis) (5.2.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->pyLDAvis) (2.0.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from numexpr->pyLDAvis) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->numexpr->pyLDAvis) (3.0.7)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->pyLDAvis) (3.1.0)
# Building wheels for collected packages: pyLDAvis
#   Building wheel for pyLDAvis (PEP 517) ... done
#   Created wheel for pyLDAvis: filename=pyLDAvis-3.3.1-py2.py3-none-any.whl size=136898 sha256=5888ce00c0f0f87ab42f835f0accbbc6b3c0aa431424a88bba5b2a7b1210c916
#   Stored in directory: /root/.cache/pip/wheels/c9/21/f6/17bcf2667e8a68532ba2fbf6d5c72fdf4c7f7d9abfa4852d2f
# Successfully built pyLDAvis
# Installing collected packages: funcy, pyLDAvis
# Successfully installed funcy-1.17 pyLDAvis-3.3.1

# %%
from nltk import stem
import re
import nltk
nltk.download('punkt')
import emoji
from nltk.corpus import stopwords
nltk.download('stopwords')
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
#Visualizations
import plotly.express as px
import seaborn as sns
import matplotlib.pyplot as plt
import pyLDAvis
import pyLDAvis.sklearn
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

#Natural Language Processing (NLP)
import spacy
import gensim
from spacy.tokenizer import Tokenizer
from gensim.corpora import Dictionary
from gensim.models.ldamulticore import LdaMulticore
from gensim.models import CoherenceModel
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.model_selection import GridSearchCV
from pprint import pprint
# from wordcloud import STOPWORDS
# stopwords = set(STOPWORDS)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data = pd.read_csv('/content/drive/MyDrive/NLP Group/data_cleaned_version_1.csv')
data_before = pd.read_csv('/content/drive/MyDrive/NLP Group/new_data.csv')

# %% [markdown]
# ## Overview

# %%
data_before.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105599 entries, 0 to 105598
# Data columns (total 12 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   userid          105599 non-null  int64
#  1   username        105599 non-null  object
#  2   following       105599 non-null  int64
#  3   followers       105599 non-null  int64
#  4   totaltweets     105599 non-null  int64
#  5   usercreatedts   105599 non-null  object
#  6   tweetcreatedts  105599 non-null  object
#  7   retweetcount    105599 non-null  int64
#  8   text            105599 non-null  object
#  9   hashtags        105599 non-null  object
#  10  language        105599 non-null  object
#  11  favorite_count  105599 non-null  int64
# dtypes: int64(6), object(6)
# memory usage: 9.7+ MB

# %%
data_before.head()
# Out:
#                 userid        username  following  followers  totaltweets  \
# 0  1235244517307166725   InformazioneA        103        864         7999
# 1            429580982       Sec_Cyber       1105      16344       246636
# 2             31106730         samiaji        120        463        83876
# 3             16028382            WESH        353     222861       427358
# 4              9285512  whatsinitforme       3421       1332        26311
#
#          usercreatedts       tweetcreatedts  retweetcount  \
# 0  2020-03-04 16:43:53  2022-01-17 00:00:01             1
# 1  2011-12-06 04:14:04  2022-01-17 00:00:09             0
# 2  2009-04-14 12:08:45  2022-01-17 00:00:35             1
# 3  2008-08-28 15:42:42  2022-01-17 00:01:05             0
# 4  2007-10-06 22:23:39  2022-01-17 00:01:19             0
#
#                                                 text  \
# 0  #Russia #Ukraine #US \nIn the midst of the cri...
# 1  Ukraine claims Russia behind #cyberattack in '...
# 2  Ukraine says Russia behind cyberattack in 'hyb...
# 3  Ukraine says Russia behind cyberattack in 'hyb...
# 4  @BowesChay @rickyspanish81 @Russia @Rus_Emb_Ir...
#
#                                             hashtags language  favorite_count
# 0  ['russia', 'ukraine', 'us', 'moscow', 'kiev', ...       en               1
# 1                                    ['cyberattack']       en               0
# 2                                                 []       en               0
# 3                                                 []       en               2
# 4                                                 []       en               3

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 835202 entries, 0 to 835201
# Data columns (total 13 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Unnamed: 0      835202 non-null  int64
#  1   userid          835202 non-null  int64
#  2   username        835202 non-null  object
#  3   following       835202 non-null  int64
#  4   followers       835202 non-null  int64
#  5   totaltweets     835202 non-null  int64
#  6   usercreatedts   835202 non-null  object
#  7   tweetcreatedts  835202 non-null  object
#  8   retweetcount    835202 non-null  int64
#  9   text            835202 non-null  object
#  10  hashtags        835202 non-null  object
#  11  language        835202 non-null  object
#  12  favorite_count  835202 non-null  int64
# dtypes: int64(7), object(6)
# memory usage: 82.8+ MB

# %%
# drop the first index column
data.drop(columns=data.columns[0], inplace=True)

# %%
data.head()
# Out:
#                userid        username  following  followers  totaltweets  \
# 0           313480107       chavez145        939        577        69258
# 1          2170195636           d7xen       1631        214         1630
# 2          2324486774  GayEqualGlobal      34037      34867       267610
# 3          2544474997     Jmltrouille       1586       1429        28390
# 4  991781656808886272     Akan__Drama       1095       1036        22392
#
#          usercreatedts       tweetcreatedts  retweetcount  \
# 0  2011-06-08 18:31:50  2022-02-28 00:07:06           642
# 1  2013-11-06 01:34:15  2022-02-28 00:07:07             6
# 2  2014-02-02 23:23:52  2022-02-28 00:07:07          1501
# 3  2014-06-03 22:19:12  2022-02-28 00:07:08             3
# 4  2018-05-02 20:49:08  2022-02-28 00:07:08           128
#
#                                                 text  \
# 0  ⚡️New York State Governor Kathy Hokul (Democra...
# 1  Closer look at the Vasylkiv oil depot fire whi...
# 2  #Russia's state media is flipping out over our...
# 3  Ukrainian National Anthem with English transla...
# 4  JUST IN: Ukraine opens global recruitment prog...
#
#                                             hashtags language  favorite_count
# 0        [{'text': 'Russia', 'indices': [132, 139]}]       en               0
# 1  [{'text': 'osint', 'indices': [118, 124]}, {'t...       en               0
# 2          [{'text': 'Russia', 'indices': [20, 27]}]       en               0
# 3  [{'text': 'Ukraine', 'indices': [104, 112]}, {...       en               0
# 4                                                 []       en               0

# %% [markdown]
# ## Concate two dataframe together

# %%
df = pd.concat([data_before, data])
df.reset_index(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 940801 entries, 0 to 940800
# Data columns (total 13 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   index           940801 non-null  int64
#  1   userid          940801 non-null  int64
#  2   username        940801 non-null  object
#  3   following       940801 non-null  int64
#  4   followers       940801 non-null  int64
#  5   totaltweets     940801 non-null  int64
#  6   usercreatedts   940801 non-null  object
#  7   tweetcreatedts  940801 non-null  object
#  8   retweetcount    940801 non-null  int64
#  9   text            940801 non-null  object
#  10  hashtags        940801 non-null  object
#  11  language        940801 non-null  object
#  12  favorite_count  940801 non-null  int64
# dtypes: int64(7), object(6)
# memory usage: 93.3+ MB

# %%
def check_missing_value(df:pd.DataFrame, cols:List[str]) -> pd.DataFrame:
    """
    Count missing values in specified columns.
    @param df: dataframe
    @param cols: columns to be calculated
    return: summary information
    """
    res = pd.DataFrame(cols, columns=['Feature'])
    na_cnts = [sum(df[col].isna()) for col in cols]
    res['NA Count'] = na_cnts
    res['NA Rate'] = res['NA Count'] / df.shape[0]
    res = res[res['NA Count'] != 0]
    res = res.sort_values(by='NA Count', ascending=False).reset_index(drop=True)
    return res

# %%
def check_zeros(df:pd.DataFrame, cols:List[str]) -> pd.DataFrame:
    """
    Count specified values in specified columns.
    @param df: dataframe
    @param cols: columns to be calculated
    return: summary information
    """
    res = pd.DataFrame(cols, columns=['Feature'])
    na_cnts = [sum(df[col] == 0) for col in cols]
    res['Value Count'] = na_cnts
    res['Rate'] = res['Value Count'] / df.shape[0]
    res = res[res['Value Count'] != 0]
    res = res.sort_values(by='Value Count', ascending=False).reset_index(drop=True)
    return res

# %%
# only these three columns have missing values
# luckily they are not too important for our model building, so we can abandon these columns
check_missing_value(data, data.columns)
# Out:
# Empty DataFrame
# Columns: [Feature, NA Count, NA Rate]
# Index: []

# %% [markdown]
# # Preprocessing

# %%
# most tweets do not get likes
check_zeros(data, data.columns)
# Out:
#           Feature  Value Count      Rate
# 0  favorite_count       669368  0.801444
# 1    retweetcount       522984  0.626177
# 2       following         4363  0.005224

# %% [markdown]
# ## Get Media list

# %%
from bs4 import BeautifulSoup
import urllib

# %%
url = "https://memeburn.com/2010/09/the-100-most-influential-news-media-twitter-accounts"
soup = BeautifulSoup(urllib.request.urlopen(url).read())

# %%
media_account_dict = {}
# get the table with media account information
account_table = soup.findAll('table')[0].tbody
for (i,row) in enumerate(account_table.findAll('tr')):
    # skip the table head
    if i == 0: continue
    # get name of each row
    user_name = row.findAll('td')[1].text
    real_name = row.findAll('td')[2].text
    # add names without @
    media_account_dict[real_name] = user_name[1:]

# %%
# export to a csv file
media_df = pd.DataFrame(list(zip(media_account_dict.keys(), media_account_dict.values())), 
                        columns=['real_name','user_name'])
media_df.head()
media_df.to_csv('media_list.csv',index=False)

# %% [markdown]
# ## Filter tweets from media and ordinary people

# %%
media_tweets_df = df[df.username.isin(media_account_dict.values())]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 63 entries, 2440 to 704729
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   index           63 non-null     int64
#  1   userid          63 non-null     int64
#  2   username        63 non-null     object
#  3   following       63 non-null     int64
#  4   followers       63 non-null     int64
#  5   totaltweets     63 non-null     int64
#  6   usercreatedts   63 non-null     object
#  7   tweetcreatedts  63 non-null     object
#  8   retweetcount    63 non-null     int64
#  9   text            63 non-null     object
#  10  hashtags        63 non-null     object
#  11  language        63 non-null     object
#  12  favorite_count  63 non-null     int64
# dtypes: int64(7), object(6)
# memory usage: 6.9+ KB

# %% [markdown]
# Since there are not too many tweets which were generated from the media list. We can also filter out Twitter account whose followers is larger than a threshold, for example 1 milliom.

# %%
follower_threshold = 100000
influencer_tweets = df[df.followers>=follower_threshold].copy()
normal_tweets = df[df.followers>=follower_threshold].copy()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 27747 entries, 3 to 940626
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   index           27747 non-null  int64
#  1   userid          27747 non-null  int64
#  2   username        27747 non-null  object
#  3   following       27747 non-null  int64
#  4   followers       27747 non-null  int64
#  5   totaltweets     27747 non-null  int64
#  6   usercreatedts   27747 non-null  object
#  7   tweetcreatedts  27747 non-null  object
#  8   retweetcount    27747 non-null  int64
#  9   text            27747 non-null  object
#  10  hashtags        27747 non-null  object
#  11  language        27747 non-null  object
#  12  favorite_count  27747 non-null  int64
# dtypes: int64(7), object(6)
# memory usage: 3.0+ MB

# %%
# convert to pandas date time for easy processing
df['tweetcreatedts'] = pd.to_datetime(df['tweetcreatedts'])
# reset the index
df = df.set_index('tweetcreatedts', drop=False)

# %% [markdown]
# ## Data Split

# %%
# split all the tweets to tweets per day
date_list = [str(i) for i in np.unique(df.index.date)]
text_dict = {}
for date in date_list:
    text_dict[date] = list(df.loc[date].text)

# %% [markdown]
# ## Data Cleaning

# %%
def give_emoji_free_text(text):
    """
    Removes emoji's from tweets
    Accepts:
        Text (tweets)
    Returns:
        Text (emoji free tweets)
    """
    emoji_list = [c for c in text if c in emoji.UNICODE_EMOJI]
    clean_text = ' '.join([str for str in text.split() if not any(i in str for i in emoji_list)])
    return clean_text

def clean_message(message):
    '''
    Input:
        message: a string containing a message.
    Output:
        messages_cleaned: a list of words containing the processed message. 

    '''
    # remove emoji
    message = give_emoji_free_text(message)
    # remove links
    message = re.sub(r'^https?:\/\/.*[\r\n]*', '', message, flags=re.MULTILINE)
    # remove punctuations
    message = re.sub(r'[^\w\s]', '', message)
    # remove stopwords
    text_tokens = word_tokenize(message)
    messages_no_stopwords = [word for word in text_tokens if not word in stopwords.words('english')]
    # stemming
    ps = PorterStemmer()
    messages_cleaned = []
    for word in messages_no_stopwords:
        messages_cleaned.append(ps.stem(word))
        
    return ' '.join(messages_cleaned)

# %%
for date, text_list in tqdm(text_dict.items()):
    cleaned_text = [clean_message(i) for i in text_list[:1000]]
    text_dict[date] = cleaned_text
# Out:
# 100%|██████████| 25/25 [01:45<00:00,  4.20s/it]

# %% [markdown]
# # Modeling

# %% [markdown]
# ## Baseline

# %%
# let's first get the baseline model from tweets data on 01-17
tweet_list = text_dict['2022-01-17']

# %%
vectorizer = CountVectorizer(
analyzer='word',       
min_df=3,# minimum required occurences of a word 
lowercase=True,# convert all words to lowercase
token_pattern='[a-zA-Z0-9]{3,}',# num chars > 3
max_features=5000,# max number of unique words
                            )
data_matrix = vectorizer.fit_transform(tweet_list)
# Out:
# <1000x1097 sparse matrix of type '<class 'numpy.int64'>'
# 	with 12338 stored elements in Compressed Sparse Row format>

# %%
# I will use LDA to create topics along with the probability distribution for each word in our vocabulary for each topic
lda_model = LatentDirichletAllocation(
n_components=5, # Number of topics
learning_method='online',
random_state=20,       
n_jobs = -1  # Use all available CPUs
                                     )
lda_output = lda_model.fit_transform(data_matrix)

# %% [markdown]
# ## Evaluation

# %%
# Log Likelyhood: Higher the better
print("Log Likelihood: ", lda_model.score(data_matrix))

# Perplexity: Lower the better. Perplexity = exp(-1. * log-likelihood per word)
print("Perplexity: ", lda_model.perplexity(data_matrix))

# See model parameters
pprint(lda_model.get_params())
# Out:
# Log Likelihood:  -82387.48862423307
# Perplexity:  509.9903860740477
# {'batch_size': 128,
#  'doc_topic_prior': None,
#  'evaluate_every': -1,
#  'learning_decay': 0.7,
#  'learning_method': 'online',
#  'learning_offset': 10.0,
#  'max_doc_update_iter': 100,
#  'max_iter': 10,
#  'mean_change_tol': 0.001,
#  'n_components': 5,
#  'n_jobs': -1,
#  'perp_tol': 0.1,
#  'random_state': 20,
#  'topic_word_prior': None,
#  'total_samples': 1000000.0,
#  'verbose': 0}

# %% [markdown]
# ## Visualization

# %%
#pyLDAvis extracts information from a fitted LDA topic model to inform an interactive web-based visualization
pyLDAvis.enable_notebook()
pyLDAvis.sklearn.prepare(lda_model, data_matrix, vectorizer, mds='tsne')
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.7/dist-packages/pyLDAvis/_prepare.py:247: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   by='saliency', ascending=False).head(R).drop('saliency', 1)
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:827: FutureWarning: 'square_distances' has been introduced in 0.24 to help phase out legacy squaring behavior. The 'legacy' setting will be removed in 1.1 (renaming of 0.26), and the default setting will be changed to True. In 1.3, 'square_distances' will be removed altogether, and distances will be squared by default. Set 'square_distances'=True to silence this warning.
#   FutureWarning,
# PreparedData(topic_coordinates=                x           y  topics  cluster       Freq
# topic
# 1      150.222153  -72.269554       1        1  59.783150
# 3       51.163364 -159.968018       2        1  15.356200
# 4      -73.144554   21.523815       3        1  12.177854
# 0      -66.410133 -110.606438       4        1   8.475104
# 2       54.417324   12.443444       5        1   4.207692, topic_info=         Term        Freq       Total Category  logprob  loglift
# 1008   ukrain  937.000000  937.000000  Default  30.0000  30.0000
# 647      nato  435.000000  435.000000  Default  29.0000  29.0000
# 843   russian  249.000000  249.000000  Default  28.0000  28.0000
# 1048      war  343.000000  343.000000  Default  27.0000  27.0000
# 776     putin  185.000000  185.000000  Default  26.0000  26.0000
# ...       ...         ...         ...      ...      ...      ...
# 794    recent    3.921646    7.827521   Topic5  -4.9543   2.4771
# 841    russia    4.993066  605.877495   Topic5  -4.7128  -1.6304
# 647      nato    4.293807  435.204432   Topic5  -4.8637  -1.4504
# 160     chang    3.489595   15.977181   Topic5  -5.0711   1.6469
# 472    hybrid    3.534878   59.220355   Topic5  -5.0582   0.3497
#
# [285 rows x 6 columns], token_table=      Topic      Freq    Term
# term
# 2         1  0.945840  100000
# 8         5  0.719321    aapl
# 10        4  0.858185     abc
# 24        5  0.719351     adb
# 25        3  0.872148   addit
# ...     ...       ...     ...
# 1092      3  0.944594    yeah
# 1093      1  0.548431    year
# 1093      2  0.054843    year
# 1093      3  0.054843    year
# 1093      4  0.301637    year
#
# [369 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[2, 4, 5, 1, 3])

# %%
#  top 5 most frequent words from each topic that found by LDA
for i,topic in enumerate(lda_model.components_):
    print('Top 5 words for topic:',i)
    print([vectorizer.get_feature_names()[i] for i in topic.argsort()[-5:]])
    print('\n')
# Out:
# Top 5 words for topic: 0
# ['attack', 'belaru', 'troop', 'war', 'russian']
#
#
# Top 5 words for topic: 1
# ['russian', 'war', 'nato', 'russia', 'ukrain']
#
#
# Top 5 words for topic: 2
# ['forev', 'attack', 'war', 'ukrain', 'cyber']
#
#
# Top 5 words for topic: 3
# ['war', 'putin', 'russia', 'nato', 'ukrain']
#
#
# Top 5 words for topic: 4
# ['war', 'need', 'west', 'nato', 'ukrain']
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %% [markdown]
# ## Hyperparameter Tuning

# %%
# Define Search Param
search_params = {'n_components': [3, 5, 10, 15], 'learning_decay': [.5, .7, .9]}

# Init the Model
lda = LatentDirichletAllocation()

# Init Grid Search Class
model = GridSearchCV(lda, param_grid=search_params)

# Do the Grid Search
model.fit(data_matrix)
# Out:
# GridSearchCV(estimator=LatentDirichletAllocation(),
#              param_grid={'learning_decay': [0.5, 0.7, 0.9],
#                          'n_components': [3, 5, 10, 15]})

# %%
# Best Model
best_lda_model = model.best_estimator_

# Model Parameters
print("Best Model's Params: ", model.best_params_)

# Log Likelihood Score
print("Best Log Likelihood Score: ", model.best_score_)

# Perplexity
print("Model Perplexity: ", best_lda_model.perplexity(data_matrix))
# Out:
# Best Model's Params:  {'learning_decay': 0.7, 'n_components': 3}
# Best Log Likelihood Score:  -19223.79639669488
# Model Perplexity:  466.92043963331474

# %% [markdown]
# ## Topic Modeling Per Day

# %%
def generate_daily_topic(text_dict: dict, topic_num: int, learning_decay: float):

    # initilize array to store topics
    topic_table = np.empty([len(text_dict), topic_num], dtype=object)

    # loop every day data
    row = 0
    for date, text_list in tqdm(text_dict.items()):

        vectorizer = CountVectorizer(
        analyzer='word',       
        min_df=3,# minimum required occurences of a word 
        lowercase=True,# convert all words to lowercase
        token_pattern='[a-zA-Z0-9]{3,}',# num chars > 3
        max_features=5000,# max number of unique words
                                    )
        data_matrix = vectorizer.fit_transform(text_list)

        lda_model = LatentDirichletAllocation(
        n_components=topic_num,
        learning_decay=learning_decay,
        learning_method='online',
        random_state=20,       
        n_jobs = -1  # Use all available CPUs
                                            )
        lda_model.fit_transform(data_matrix)

        for i,topic in enumerate(lda_model.components_):
            topics = str([vectorizer.get_feature_names()[i] for i in topic.argsort()[-5:]])
            topic_table[row, i] = topics
        row += 1
    
    # return it as a dataframe
    topic_df = pd.DataFrame(topic_table)
    topic_df.index = list(text_dict.keys())
    topic_df.columns = ['topic_'+str(i) for i in range(topic_num)]
    return topic_df

# %%
daily_topics = generate_daily_topic(text_dict, 3, 0.7)
# Out:
#   0%|          | 0/25 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
#   4%|▍         | 1/25 [00:05<02:20,  5.84s/it]
# ['invad', 'war', 'nato', 'russia', 'ukrain']
# ['troop', 'nato', 'russian', 'russia', 'ukrain']
# ['use', 'troop', 'russian', 'war', 'ukrain']
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
#   8%|▊         | 2/25 [00:08<01:37,  4.26s/it]
# ['russian', 'war', 'nato', 'russia', 'ukrain']
# ['europ', 'whi', 'crisi', 'ukrain', 'war']
# ['border', 'russian', 'troop', 'russia', 'ukrain']
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
#  12%|█▏        | 3/25 [00:12<01:23,  3.78s/it]
# ['biden', 'russian', 'border', 'troop', 'ukrain']
# ['troop', 'invad', 'border', 'russia', 'ukrain']
# ['troop', 'the', 'invad', 'ukrain', 'russia']
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
#  16%|█▌        | 4/25 [00:15<01:12,  3.47s/it]
# ['want', 'border', 'invad', 'ukrain', 'russia']
# ['russia', 'russian', 'border', 'troop', 'ukrain']
# ['troop', 'russian', 'good', 'medici1', 'expressnew']
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
#  20%|██        | 5/25 [00:17<01:04,  3.23s/it]
# ['russian', 'stand', 'putin', 'ukrain', 'standwithukrain']
# ['troop', 'russia', 'russian', 'border', 'ukrain']
# ['show', 'destroy', 'russian', 'ukrain', 'border']
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
#  24%|██▍       | 6/25 [00:20<00:57,  3.03s/it]
# ['russia', 'russian', 'stand', 'border', 'ukrain']
# ['russia', 'world', 'putin', 'ukrain', 'standwithukrain']
# ['russia', 'potu', 'sanction', 'putin', 'standwithukrain']
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
#  28%|██▊       | 7/25 [00:24<00:57,  3.20s/it]
# ['troop', 'cross', 'russian', 'border', 'ukrain']
# ['russia', 'nato', 'russian', 'border', 'ukrain']
# ['troop', 'attack', 'russian', 'border', 'ukrain']
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
#  32%|███▏      | 8/25 [00:27<00:53,  3.13s/it]
# ['russia', 'nato', 'russian', 'border', 'ukrain']
# ['chernivtsi', 'offic', 'russian', 'border', 'ukrain']
# ['ukrainian', 'guard', 'ukrain', 'border', 'russian']
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
#  36%|███▌      | 9/25 [00:30<00:49,  3.12s/it]
# ['russian', 'putin', 'ukrainerussiawar', 'russia', 'ukrain']
# ['russiaukrainewar', 'peopl', 'russian', 'russia', 'ukrain']
# ['the', 'war', 'russia', 'putin', 'ukrain']
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
#  40%|████      | 10/25 [00:33<00:46,  3.11s/it]
# ['war', 'amp', 'putin', 'russia', 'ukrain']
# ['war', 'ukrainian', 'russian', 'ukrainerussiawar', 'ukrain']
# ['kyiv', 'russian', 'putin', 'russia', 'ukrain']
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
#  44%|████▍     | 11/25 [00:36<00:43,  3.07s/it]
# ['amp', 'peopl', 'the', 'russia', 'ukrain']
# ['forc', 'ukrainian', 'russia', 'russian', 'ukrain']
# ['kyiv', 'ukrainerussiawar', 'putin', 'russia', 'ukrain']
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
#  48%|████▊     | 12/25 [00:39<00:38,  2.98s/it]
# ['russian', 'power', 'plant', 'nuclear', 'ukrain']
# ['russiaukrainewar', 'ukrainerussianwar', 'putin', 'russia', 'ukrain']
# ['amp', 'war', 'putin', 'russia', 'ukrain']
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
#  52%|█████▏    | 13/25 [00:41<00:34,  2.91s/it]
# ['war', 'ukrainian', 'russian', 'russia', 'ukrain']
# ['talk', 'countri', 'watch', 'ukrain', 'putin']
# ['peopl', 'amp', 'russia', 'putin', 'ukrain']
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
#  56%|█████▌    | 14/25 [00:44<00:32,  2.92s/it]
# ['putin', 'nato', 'russia', 'russian', 'ukrain']
# ['ukrainerussianwar', 'putin', 'russian', 'russia', 'ukrain']
# ['war', 'the', 'amp', 'russia', 'ukrain']
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
#  60%|██████    | 15/25 [00:47<00:28,  2.89s/it]
# ['war', 'russian', 'putin', 'russia', 'ukrain']
# ['oil', 'women', 'the', 'russia', 'ukrain']
# ['slavaukraini', 'end', 'kill', 'ukrain', 'russia']
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
#  64%|██████▍   | 16/25 [00:50<00:25,  2.82s/it]
# ['the', 'russian', 'putin', 'russia', 'ukrain']
# ['the', 'whi', 'amp', 'peopl', 'ukrain']
# ['you', 'war', 'ukrain', 'putin', 'standwithukrain']
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
#  68%|██████▊   | 17/25 [00:53<00:22,  2.86s/it]
# ['war', 'amp', 'russia', 'putin', 'ukrain']
# ['break', 'iraq', 'ukrainewar', 'russia', 'ukrain']
# ['the', 'putin', 'standwithukrain', 'russian', 'ukrain']
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
#  72%|███████▏  | 18/25 [00:55<00:19,  2.80s/it]
# ['ukrain', 'watch', 'pleas', 'video', 'anonym']
# ['stopwar', 'stopputin', 'peopl', 'standwithukrain', 'ukrain']
# ['russian', 'putin', 'war', 'russia', 'ukrain']
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
#  76%|███████▌  | 19/25 [00:58<00:16,  2.81s/it]
# ['ukrainewar', 'putin', 'russian', 'russia', 'ukrain']
# ['war', 'standwithukrain', 'russian', 'putin', 'ukrain']
# ['war', 'countri', 'world', 'the', 'ukrain']
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
#  80%|████████  | 20/25 [01:01<00:13,  2.72s/it]
# ['nexta', 'dont', 'slavaukraini', 'putin', 'standwithukrain']
# ['war', 'putin', 'russian', 'russia', 'ukrain']
# ['russian', 'amp', 'putin', 'russia', 'ukrain']
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
#  84%|████████▍ | 21/25 [01:04<00:11,  2.75s/it]
# ['biden', 'war', 'putin', 'russia', 'ukrain']
# ['standwithukrain', 'russian', 'get', 'peopl', 'ukrain']
# ['ukrainian', 'putin', 'russian', 'russia', 'ukrain']
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
#  88%|████████▊ | 22/25 [01:07<00:08,  2.84s/it]
# ['ukrainian', 'standwithukrain', 'putin', 'russia', 'ukrain']
# ['the', 'war', 'amp', 'russian', 'ukrain']
# ['mariupol', 'russian', 'russia', 'war', 'ukrain']
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
#  92%|█████████▏| 23/25 [01:10<00:05,  2.86s/it]
# ['peopl', 'russian', 'russia', 'putin', 'ukrain']
# ['the', 'putin', 'russia', 'ukrain', 'standwithukrain']
# ['war', 'standwithukrain', 'russian', 'russia', 'ukrain']
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
#  96%|█████████▌| 24/25 [01:12<00:02,  2.81s/it]
# ['stop', 'ukrain', 'peopl', 'war', 'putin']
# ['war', 'ukrainian', 'russian', 'russia', 'ukrain']
# ['slavaukraini', 'russian', 'sanction', 'ukrain', 'russia']
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# 100%|██████████| 25/25 [01:15<00:00,  3.02s/it]
# ['thousand', 'tell', 'putin', 'russian', 'ukrain']
# ['russian', 'war', 'putin', 'russia', 'ukrain']
# ['russia', 'militari', 'ukrainian', 'russian', 'ukrain']

# %%
daily_topics
# Out:
#                                                       topic_0  \
# 2022-01-17       ['invad', 'war', 'nato', 'russia', 'ukrain']
# 2022-01-18     ['russian', 'war', 'nato', 'russia', 'ukrain']
# 2022-01-24  ['biden', 'russian', 'border', 'troop', 'ukrain']
# 2022-01-25    ['want', 'border', 'invad', 'ukrain', 'russia']
# 2022-02-21  ['russian', 'stand', 'putin', 'ukrain', 'stand...
# 2022-02-22  ['russia', 'russian', 'stand', 'border', 'ukra...
# 2022-02-24  ['troop', 'cross', 'russian', 'border', 'ukrain']
# 2022-02-25  ['russia', 'nato', 'russian', 'border', 'ukrain']
# 2022-02-28  ['russian', 'putin', 'ukrainerussiawar', 'russ...
# 2022-03-01        ['war', 'amp', 'putin', 'russia', 'ukrain']
# 2022-03-03        ['amp', 'peopl', 'the', 'russia', 'ukrain']
# 2022-03-04  ['russian', 'power', 'plant', 'nuclear', 'ukra...
# 2022-03-05  ['war', 'ukrainian', 'russian', 'russia', 'ukr...
# 2022-03-08   ['putin', 'nato', 'russia', 'russian', 'ukrain']
# 2022-03-09    ['war', 'russian', 'putin', 'russia', 'ukrain']
# 2022-03-10    ['the', 'russian', 'putin', 'russia', 'ukrain']
# 2022-03-13        ['war', 'amp', 'russia', 'putin', 'ukrain']
# 2022-03-14    ['ukrain', 'watch', 'pleas', 'video', 'anonym']
# 2022-03-15  ['ukrainewar', 'putin', 'russian', 'russia', '...
# 2022-03-16  ['nexta', 'dont', 'slavaukraini', 'putin', 'st...
# 2022-03-17      ['biden', 'war', 'putin', 'russia', 'ukrain']
# 2022-03-20  ['ukrainian', 'standwithukrain', 'putin', 'rus...
# 2022-03-21  ['peopl', 'russian', 'russia', 'putin', 'ukrain']
# 2022-03-25        ['stop', 'ukrain', 'peopl', 'war', 'putin']
# 2022-03-26  ['thousand', 'tell', 'putin', 'russian', 'ukra...
#
#                                                       topic_1  \
# 2022-01-17   ['troop', 'nato', 'russian', 'russia', 'ukrain']
# 2022-01-18         ['europ', 'whi', 'crisi', 'ukrain', 'war']
# 2022-01-24   ['troop', 'invad', 'border', 'russia', 'ukrain']
# 2022-01-25  ['russia', 'russian', 'border', 'troop', 'ukra...
# 2022-02-21  ['troop', 'russia', 'russian', 'border', 'ukra...
# 2022-02-22  ['russia', 'world', 'putin', 'ukrain', 'standw...
# 2022-02-24  ['russia', 'nato', 'russian', 'border', 'ukrain']
# 2022-02-25  ['chernivtsi', 'offic', 'russian', 'border', '...
# 2022-02-28  ['russiaukrainewar', 'peopl', 'russian', 'russ...
# 2022-03-01  ['war', 'ukrainian', 'russian', 'ukrainerussia...
# 2022-03-03  ['forc', 'ukrainian', 'russia', 'russian', 'uk...
# 2022-03-04  ['russiaukrainewar', 'ukrainerussianwar', 'put...
# 2022-03-05    ['talk', 'countri', 'watch', 'ukrain', 'putin']
# 2022-03-08  ['ukrainerussianwar', 'putin', 'russian', 'rus...
# 2022-03-09        ['oil', 'women', 'the', 'russia', 'ukrain']
# 2022-03-10           ['the', 'whi', 'amp', 'peopl', 'ukrain']
# 2022-03-13  ['break', 'iraq', 'ukrainewar', 'russia', 'ukr...
# 2022-03-14  ['stopwar', 'stopputin', 'peopl', 'standwithuk...
# 2022-03-15  ['war', 'standwithukrain', 'russian', 'putin',...
# 2022-03-16    ['war', 'putin', 'russian', 'russia', 'ukrain']
# 2022-03-17  ['standwithukrain', 'russian', 'get', 'peopl',...
# 2022-03-20         ['the', 'war', 'amp', 'russian', 'ukrain']
# 2022-03-21  ['the', 'putin', 'russia', 'ukrain', 'standwit...
# 2022-03-25  ['war', 'ukrainian', 'russian', 'russia', 'ukr...
# 2022-03-26    ['russian', 'war', 'putin', 'russia', 'ukrain']
#
#                                                       topic_2
# 2022-01-17       ['use', 'troop', 'russian', 'war', 'ukrain']
# 2022-01-18  ['border', 'russian', 'troop', 'russia', 'ukra...
# 2022-01-24      ['troop', 'the', 'invad', 'ukrain', 'russia']
# 2022-01-25  ['troop', 'russian', 'good', 'medici1', 'expre...
# 2022-02-21  ['show', 'destroy', 'russian', 'ukrain', 'bord...
# 2022-02-22  ['russia', 'potu', 'sanction', 'putin', 'stand...
# 2022-02-24  ['troop', 'attack', 'russian', 'border', 'ukra...
# 2022-02-25  ['ukrainian', 'guard', 'ukrain', 'border', 'ru...
# 2022-02-28        ['the', 'war', 'russia', 'putin', 'ukrain']
# 2022-03-01   ['kyiv', 'russian', 'putin', 'russia', 'ukrain']
# 2022-03-03  ['kyiv', 'ukrainerussiawar', 'putin', 'russia'...
# 2022-03-04        ['amp', 'war', 'putin', 'russia', 'ukrain']
# 2022-03-05      ['peopl', 'amp', 'russia', 'putin', 'ukrain']
# 2022-03-08          ['war', 'the', 'amp', 'russia', 'ukrain']
# 2022-03-09  ['slavaukraini', 'end', 'kill', 'ukrain', 'rus...
# 2022-03-10  ['you', 'war', 'ukrain', 'putin', 'standwithuk...
# 2022-03-13  ['the', 'putin', 'standwithukrain', 'russian',...
# 2022-03-14    ['russian', 'putin', 'war', 'russia', 'ukrain']
# 2022-03-15       ['war', 'countri', 'world', 'the', 'ukrain']
# 2022-03-16    ['russian', 'amp', 'putin', 'russia', 'ukrain']
# 2022-03-17  ['ukrainian', 'putin', 'russian', 'russia', 'u...
# 2022-03-20  ['mariupol', 'russian', 'russia', 'war', 'ukra...
# 2022-03-21  ['war', 'standwithukrain', 'russian', 'russia'...
# 2022-03-25  ['slavaukraini', 'russian', 'sanction', 'ukrai...
# 2022-03-26  ['russia', 'militari', 'ukrainian', 'russian',...
