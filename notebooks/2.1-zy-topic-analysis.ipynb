# %%
import re
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud

# %%
daily_topics = pd.read_csv('../data/processed/daily_topics.csv')
influencer_daily_topics = pd.read_csv('../data/processed/influencer_daily_topics.csv')
normal_daily_topics = pd.read_csv('../data/processed/normal_daily_topics.csv')

# %%
def get_topics_df(df):
    all_topics = df.topic_0 + df.topic_1 + df.topic_2
    all = ''.join(list(all_topics))
    all_topic_list = re.findall(r"'(.*?)'", all)
    return pd.DataFrame(all_topic_list)

# %%
daily_topic_df = get_topics_df(daily_topics)
inf_daily_topic_df = get_topics_df(influencer_daily_topics)
normal_daily_topic_df = get_topics_df(normal_daily_topics)

# %%
daily_topic_df.value_counts()
# Out:
# ukrain                    73
# russia                    55
# war                       33
# russian                   28
# putin                     27
# standwithukrain           18
# nato                      18
# amp                       15
# ukrainian                 13
# peopl                     13
# troop                     11
# the                        7
# kyiv                       6
# border                     6
# invad                      5
# ukrainerussiawar           5
# ukrainewar                 5
# support                    4
# help                       4
# mariupol                   3
# stoprussia                 2
# slavaukraini               2
# world                      2
# china                      2
# see                        1
# day                        1
# women                      1
# bbcqt                      1
# video                      1
# belaru                     1
# biden                      1
# ukraineunderattack         1
# ...

# %%
inf_daily_topic_df.value_counts()
# Out:
# ukrain     75
# russia     59
# russian    37
# war        26
# the        18
#            ..
# minist      1
# alert       1
# oil         1
# order       1
# women       1
# Length: 64, dtype: int64

# %%
normal_daily_topic_df.value_counts()
# Out:
# ukrain                    74
# russia                    51
# war                       32
# russian                   31
# putin                     31
# amp                       20
# standwithukrain           17
# nato                      17
# peopl                     12
# ukrainian                 12
# troop                     10
# mariupol                   6
# kyiv                       6
# invad                      5
# the                        5
# border                     5
# help                       3
# ukrainerussiawar           3
# ukrainewar                 3
# biden                      3
# stop                       3
# support                    2
# stpatricksday              2
# presid                     2
# day                        2
# slavaukraini               2
# stand                      2
# trump                      1
# 8500                       1
# russianukrainianwar        1
# alert                      1
# order                      1
# ...

# %% [markdown]
# # Visualization

# %%
def generate_wordcloud(df):
    wordcloud = WordCloud(background_color='white',
                          max_words=200,
                          max_font_size=40,
                          scale=3,
                          random_state=1,
                          colormap='viridis').generate(' '.join(list(df[0])))
    plt.figure(figsize=(20, 10))
    plt.imshow(wordcloud, interpolation="bilinear")
    plt.axis("off")
    plt.show()

# %%
generate_wordcloud(daily_topic_df)

# %%
generate_wordcloud(inf_daily_topic_df)

# %%
generate_wordcloud(normal_daily_topic_df)
