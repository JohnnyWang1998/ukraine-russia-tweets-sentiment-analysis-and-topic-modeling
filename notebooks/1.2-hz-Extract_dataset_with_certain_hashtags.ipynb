# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('new_data.csv', sep = ',', encoding = 'latin-1')
df.head(5)
# Out:
#                 userid        username  following  followers  totaltweets  \
# 0  1235244517307166725   InformazioneA        103        864         7999
# 1            429580982       Sec_Cyber       1105      16344       246636
# 2             31106730         samiaji        120        463        83876
# 3             16028382            WESH        353     222861       427358
# 4              9285512  whatsinitforme       3421       1332        26311
#
#          usercreatedts       tweetcreatedts  retweetcount  \
# 0  2020-03-04 16:43:53  2022-01-17 00:00:01             1
# 1  2011-12-06 04:14:04  2022-01-17 00:00:09             0
# 2  2009-04-14 12:08:45  2022-01-17 00:00:35             1
# 3  2008-08-28 15:42:42  2022-01-17 00:01:05             0
# 4  2007-10-06 22:23:39  2022-01-17 00:01:19             0
#
#                                                 text  \
# 0  #Russia #Ukraine #US \nIn the midst of the cri...
# 1  Ukraine claims Russia behind #cyberattack in '...
# ...

# %%
#Tweets that contain hashtag "putin"
putin_index = df.hashtags.str.contains('putin')
putin_data = df[putin_index]

# %%
putin_data.head(5)
# Out:
#                  userid       username  following  followers  totaltweets  \
# 19            218949823      Hellacort      11565      11620        36460
# 26  1127253218759716864  CourtttJester       1115       1281         7163
# 52            257088949       mycomfor        154        464       235484
# 59            783046681   10WallStreet        544        838       165128
# 63           2305780065     UNISdirect       2328       1194        11399
#
#           usercreatedts       tweetcreatedts  retweetcount  \
# 19  2010-11-23 15:07:59  2022-01-17 00:10:27             2
# 26  2019-05-11 16:44:45  2022-01-17 00:12:24             0
# 52  2011-02-24 18:12:42  2022-01-17 00:30:05             0
# 59  2012-08-26 19:26:27  2022-01-17 00:32:39             1
# 63  2014-01-26 14:26:07  2022-01-17 00:33:50             3
#
#                                                  text  \
# 19  If Vladimir Putin cared about #Russia and the ...
# ...

# %%
#Tweets that contain hashtag "nato"
nato_index = df.hashtags.str.contains('nato')
nato_data = df[nato_index]

# %%
nato_data.head(5)
# Out:
#                  userid         username  following  followers  totaltweets  \
# 25             12896172  littlebytesnews      13339      20671      1267323
# 26  1127253218759716864    CourtttJester       1115       1281         7163
# 35   757994827241885696     bamnecessary       1929       6146         9597
# 59            783046681     10WallStreet        544        838       165128
# 63           2305780065       UNISdirect       2328       1194        11399
#
#           usercreatedts       tweetcreatedts  retweetcount  \
# 25  2008-01-31 01:53:37  2022-01-17 00:12:20             0
# 26  2019-05-11 16:44:45  2022-01-17 00:12:24             0
# 35  2016-07-26 17:43:44  2022-01-17 00:19:41             7
# 59  2012-08-26 19:26:27  2022-01-17 00:32:39             1
# 63  2014-01-26 14:26:07  2022-01-17 00:33:50             3
#
#                                                  text  \
# 25  RT:\n\nThereâs an urgent need to resolve the...
# ...

# %%
#Tweets that contain hashtag "ukraine"
ukraine_index = df.hashtags.str.contains('ukraine')
ukraine_data = df[ukraine_index]

# %%
ukraine_data.head(5)
# Out:
#                  userid         username  following  followers  totaltweets  \
# 0   1235244517307166725    InformazioneA        103        864         7999
# 5   1131617735434285056  MichaelDeMatteo        101        548         3001
# 8    731463062230700032    robert_zubrin       3994      16108        23285
# 19            218949823        Hellacort      11565      11620        36460
# 25             12896172  littlebytesnews      13339      20671      1267323
#
#           usercreatedts       tweetcreatedts  retweetcount  \
# 0   2020-03-04 16:43:53  2022-01-17 00:00:01             1
# 5   2019-05-23 17:47:47  2022-01-17 00:02:00             0
# 8   2016-05-14 12:35:58  2022-01-17 00:04:06             6
# 19  2010-11-23 15:07:59  2022-01-17 00:10:27             2
# 25  2008-01-31 01:53:37  2022-01-17 00:12:20             0
#
#                                                  text  \
# 0   #Russia #Ukraine #US \nIn the midst of the cri...
# ...
